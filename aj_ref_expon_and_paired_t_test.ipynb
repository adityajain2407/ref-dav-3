# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/ref-dav-3/blob/main/aj_ref_expon_and_paired_t_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2023-09-15 at 6.28.11 PM.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import expon

from scipy.stats import ttest_rel

# %% [markdown]
# # Expon

# %%
#scale is avg waiting time between 2 occurances of an evenet

# %%
# P[T > 6]
1 - expon.cdf(x=6, scale=5)
# Out:
# 0.3011942119122022

# %%
# P[T > 9 | T > 3]
(1 - expon.cdf(x=9, scale=5))/(1 - expon.cdf(x=3, scale=5))
# Out:
# 0.30119421191220214

# %% [markdown]
# # Paired T-Test

# %% [markdown]
# Will problem solving sessions help students?
#
# Test 1: Before the session
#
# Test 2: After the session

# %%
df_ps = pd.read_csv("problem_solving.csv")

# %%
len(df_ps)
# Out:
# 137

# %%
df_ps.head()
# Out:
#    id  test_1  test_2
# 0   0      40      38
# 1   1      49      44
# 2   2      65      69
# 3   3      59      63
# 4   4      44      43

# %%
df_ps.describe()
# Out:
#                id      test_1      test_2
# count  137.000000  137.000000  137.000000
# mean    68.000000   60.489051   62.430657
# std     39.692569   17.080311   17.516293
# min      0.000000   30.000000   27.000000
# 25%     34.000000   46.000000   48.000000
# 50%     68.000000   59.000000   62.000000
# 75%    102.000000   75.000000   77.000000
# max    136.000000   89.000000   96.000000

# %%
# H0: Problem solving has no effect
# Ha: Problem solving had an effect
ttest_rel(df_ps["test_1"], df_ps["test_2"])
# Out:
# TtestResult(statistic=-5.502886353508166, pvalue=1.795840353792307e-07, df=136)

# %%
# H0: Problem solving has no effect
# Ha: Problem solving improved the scores
ttest_rel(df_ps["test_1"], df_ps["test_2"], alternative="less")
# Out:
# TtestResult(statistic=-5.502886353508166, pvalue=8.979201768961535e-08, df=136)

# %%
# H0: Problem solving has no effect
# Ha: Problem solving deteriorated the scores
ttest_rel(df_ps["test_1"], df_ps["test_2"], alternative="greater")
# Out:
# TtestResult(statistic=-5.502886353508166, pvalue=0.9999999102079823, df=136)
